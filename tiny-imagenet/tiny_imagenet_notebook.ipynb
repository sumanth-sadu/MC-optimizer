# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Download tiny-imagenet dataset 
# !wget http://cs231n.stanford.edu/tiny-imagenet-200.zip
# Out:
# --2022-02-02 14:59:49--  http://cs231n.stanford.edu/tiny-imagenet-200.zip
# Resolving cs231n.stanford.edu (cs231n.stanford.edu)... 171.64.68.10
# Connecting to cs231n.stanford.edu (cs231n.stanford.edu)|171.64.68.10|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248100043 (237M) [application/zip]
# Saving to: ‘tiny-imagenet-200.zip’
#
# tiny-imagenet-200.z 100%[===================>] 236.61M  37.0MB/s    in 7.5s
#
# 2022-02-02 14:59:57 (31.4 MB/s) - ‘tiny-imagenet-200.zip’ saved [248100043/248100043]

# %%
! unzip "/content/tiny-imagenet-200.zip"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: tiny-imagenet-200/val/images/val_3979.JPEG
#   inflating: tiny-imagenet-200/val/images/val_3963.JPEG
#   inflating: tiny-imagenet-200/val/images/val_7199.JPEG
#   inflating: tiny-imagenet-200/val/images/val_2752.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9687.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9407.JPEG
#   inflating: tiny-imagenet-200/val/images/val_3603.JPEG
#   inflating: tiny-imagenet-200/val/images/val_3412.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6982.JPEG
#   inflating: tiny-imagenet-200/val/images/val_8496.JPEG
#   inflating: tiny-imagenet-200/val/images/val_7332.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9241.JPEG
#   inflating: tiny-imagenet-200/val/images/val_4196.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5980.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6697.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9969.JPEG
# ...

# %%
# !rm -r /tiny-imagenet-200/test

# %%
# Run val_format.py file used to prepare the folder structure. 
# !python3 val_format.py

# %%
# Run resize.py file to resize the images to 32 by 32.
# !python resize.py
# Out:
# Streaming output truncated to the last 5000 lines.
# /content/tiny-imagenet-200/val/n03089624/val_8496.JPEG
# /content/tiny-imagenet-200/val/n03089624/val_2553.JPEG
# /content/tiny-imagenet-200/val/n03089624/val_2798.JPEG
# /content/tiny-imagenet-200/val/n03089624/val_5435.JPEG
# /content/tiny-imagenet-200/val/n03089624/val_5876.JPEG
# /content/tiny-imagenet-200/val/n03089624/val_7955.JPEG
# /content/tiny-imagenet-200/val/n03089624/val_1854.JPEG
# /content/tiny-imagenet-200/val/n03089624/val_4457.JPEG
# /content/tiny-imagenet-200/val/n03089624/val_6812.JPEG
# /content/tiny-imagenet-200/val/n03089624/val_4177.JPEG
# /content/tiny-imagenet-200/val/n03089624/val_3260.JPEG
# /content/tiny-imagenet-200/val/n03089624/val_8800.JPEG
# /content/tiny-imagenet-200/val/n03089624/val_8417.JPEG
# /content/tiny-imagenet-200/val/n03089624/val_9005.JPEG
# /content/tiny-imagenet-200/val/n03089624/val_9935.JPEG
# /content/tiny-imagenet-200/val/n03089624/val_1047.JPEG
# ...

# %%
# !rm -r /tiny-imagenet-200/*/*/images

# %%
# !python main.py --lr 0.001 --name /checkpoints/tiny_resnet18_run1_radam_mod15_bat128 --data_dir /tiny-imagenet-200
# Out:
# ==> Preparing data..
# ==> Building model..
# enter model : 1.vgg16  2. Resnet18 : 2
# Enter optimizer : 1.Adabelief 2.RAdam 3.Adam 4. Adam_GC : 2
#
# Epoch: 0
# /content/drive/MyDrive/pytorch-tiny/RAdam.py:61: UserWarning: This overload of addcmul_ is deprecated:
# 	addcmul_(Number value, Tensor tensor1, Tensor tensor2)
# Consider using one of the following signatures instead:
# 	addcmul_(Tensor tensor1, Tensor tensor2, *, Number value) (Triggered internally at  ../torch/csrc/utils/python_arg_parser.cpp:1050.)
#   exp_avg_sq.mul_(beta2).addcmul_(1 - beta2, grad, grad)
#  [================================================================>]  Step: 1s77ms | Tot: 2m51s | Loss: 4.426 | Acc: 8.679% (8679/100000) 782/782
#  [===============================================================>.]  Step: 264ms | Tot: 2s902ms | Loss: 4.219 | Acc: 10.640% (532/5000) 40/40
# Saving model ===>
# ...
